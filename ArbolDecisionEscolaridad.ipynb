# %% [markdown]
# <a href="https://colab.research.google.com/github/JunFer1105/Arboles-de-desicion/blob/master/ArbolDecisionEscolaridad.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn import tree
import graphviz
from sklearn.tree import export_graphviz
import matplotlib.pyplot as plt
import numpy as np
#SI 1 NO 0
arbol = tree.DecisionTreeClassifier()
df = pd.read_csv('EscolaridadM.csv')
df = df.sample(frac=1.0, random_state=1);
columnas = df.columns
P = np.array(df[columnas[1:3]])
print(columnas)
T = np.array(df[columnas[0]])
entrada = int(len(P)*0.7)
inP = P[:entrada]
inT = T[:entrada]
test_P = P[entrada:len(P)]
test_T = T[entrada:len(T)]
arbol.fit(inP,inT)

print("Clase Z-Zona urbana\nSexo 0-Hombre\nSexo 1-Mujer")


  
export_graphviz(arbol, out_file='arbol.dot', class_names="Discapacidad",
              feature_names=["Sexo","Edad"], impurity=False, filled=True)

with open('arbol.dot') as f:
    dot_graph=f.read()
graphviz.Source(dot_graph)
# Out:
# Index(['1EXO', 'EDAD', 'DI1CAPACIDAD', 'ULTIMO GRADO'], dtype='object')
# Clase Z-Zona urbana
# Sexo 0-Hombre
# Sexo 1-Mujer
